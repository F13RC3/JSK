# %%
import pandas as pd

# %%
df = pd.read_excel('/f_drive/Pdf of Constituencies/maharashtra (ballarpur)/Maharashtra(ballarpur).xlsx')
df.head()
# Out:
#    Assembly Constituency  Part No  Serial No                  Name  \
# 0                     72        1          1  अंजनाबाई यादव तोडासे
# 1                     72        1         18   अभिमान रघुनाथ मडावी
# 2                     72        1         38  अनिल तुकाराम. भसारकर
# 3                     72        1         39     अरुणा अनिल भसारकर
# 4                     72        1         53   अर्चना भाउराव पेटकर
#
#              Epic ID Geder  Age
# 0                        F   84
# 1         JVW0940940     M   35
# 2  MT/26/156/0000756     M   44
# 3                        F   38
# 4         JVW0941153     F   38

# %%
# df.groupby(['Part No']).count()
df.nunique()
df2 = df.drop_duplicates()

# %%
# df2.nunique()
df2.groupby(['Part No']).count()
# Out:
#          Assembly Constituency  Serial No  Name  Epic ID  Geder   Age
# Part No
# 1                          437        437   437      437    437   437
# 2                         1040       1040  1040     1040   1040  1040
# 3                          936        936   936      936    936   936
# 4                          507        507   507      507    507   507
# 5                          662        662   662      662    662   662
# 6                          193        193   193      193    193   193
# 7                         1142       1142  1142     1142   1142  1142
# 8                         1229       1229  1229     1229   1229  1229
# 9                         1027       1027  1027     1027   1027  1027
# 10                         262        262   262      262    262   262
# 11                         727        727   727      727    727   727
# 12                         992        992   992      992    992   992
# ...

# %%
import string
alpha = string.ascii_uppercase
alphaA = alpha[:6]
alphaA
# Out:
# 'ABCDEF'

# %%
hindiUnicodes = []
print(u'\u0905\u0906\u0907')
# forty = [i for i in range(40)]
# six = [i for i in range(6)]
for i in range(40):
    hindiUnicodes.append('\\u09'+str(i).zfill(2))
for j in range(6):
    hindiUnicodes.append('\\u091'+alphaA[j])
    hindiUnicodes.append('\\u092'+alphaA[j])
#     hindiUnicodes.append('093'+alphaA[j])
# Out:
# अआइ

# %%
str(29).zfill(2)[0]
len(hindiUnicodes)
hindiUnicodes = hindiUnicodes[4:]
# print(u''+hindiUnicodes[0])भ
# hindiUnicodes = hindiUnicodes[भ]

# %%
# print(u'{}'.format(hindiUnicodes[0]))
a = 'u0904'
u'\u0904'
# Out:
# 'ऄ'

# %%
# print(u''%(hindiUnicodes[0]))
hindiC = 'अइउऋऌएओअंआईऊॠॡऐऔअःऑॲकखगघङचछजझञयशहटठडढणरषतथदधनलसपफबभमव'
len(hindiC)
# hindiC[1]
# Out:
# 'इ'
