# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('E:/maharshtra/2014 Form 20.xlsx')

# %%
df.head()
# Out:
#   Serial No. of Polling Station         PB Name Keshavrao Beniram Katre  \
# 0                           NaN             NaN                     SHS
# 1                             1  Payali Bhatali                      20
# 2                             2  Payali Bhatali                      34
# 3                             3         Mohurli                      18
# 4                             4         Adegaon                       4
#
#   Prof. Dahiwade Rameshchandr a Dattatray Mungantiwar Sudhir Sachhidanand  \
# 0                                  CPI(M)                             BJP
# 1                                       1                             161
# 2                                       2                             561
# 3                                      26                             393
# 4                                       3                             195
#
#   Mulchandani Ghansham Khushimal Waman Dauji Zade Singh Rajesh Durgasingh  \
# ...

# %%
df['PB Name'][0]
df1 = df.sort_values('PB Name')
df1
# Out:
#                       Serial No. of Polling Station               PB Name  \
# 318                                             318                AASHTI
# 94                                               94               AJAYPUR
# 93                                               93               AJAYPUR
# 271                                             271                  AMTI
# 147                                             147                 ARVAT
# 4                                                 4               Adegaon
# 15                                               15  Alevahi Urf Navegaon
# 43                                               43                Ambora
# 289                                             289               BABRALA
# 269                                             269                BAMANI
# 266                                             266                BAMANI
# 267                                             267                BAMANI
# ...

# %%
print("Length of the unique names : ", len(set(df['PB Name'])))
for i in range(len(df['PB Name'])):
    if df1['PB Name'][i] == df['PB Name'][i+1]:
# Out:
# Length of the unique names :  176
