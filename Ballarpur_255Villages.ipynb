# %%
from PIL import Image
from pytesseract import image_to_string
import pytesseract
import numpy as np
import pandas as pd
import PIL
# from PIL import Image, ImageFilter, ImageEnhance
import cv2

# %%
temp = []

# %%
x = 'gisDetails/2.jpg'
im = Image.open(x)
im = cv2.bilateralFilter(np.array(im, dtype= np.uint8),9,75,75)
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
im = cv2.adaptiveThreshold(np.array(im,dtype=np.uint8), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 15)
im = Image.fromarray(im)

l = image_to_string(im)

str_list = list(filter(str.strip, l.split('\n')))
# str_list
# df

# %%
# temp.extend(str_list)

# %%
str_list1 = []
str_list2 = []
for i in range(len(str_list)):
    try:
        str_list2.append(str_list[i].split('(')[1][:-1])
        str_list1.append(str_list[i].split('(')[0][:-1])
    except:
        print('Error at : ', i)
        str_list1.append(str_list[i])
        str_list2.append(str_list[i])
    
# str_list1
# Out:
# Error at :  17

# %%
# str_list[0].split('(')[1][:-1]
# temp
# str_list2
df = pd.DataFrame(np.column_stack([str_list1, str_list2]), 
                   columns=['Value' ,'index'])
df.to_excel("/f_drive/Pdf of Constituencies/Ballarpur.xlsx",index = False)

# %%
# len(str_list1)
str_list1[17]
# Out:
# "Hardi'ué) ' W"

# %%
im
# Out:
# <PIL.Image.Image image mode=L size=3244x2312 at 0x7EFF77646860>
